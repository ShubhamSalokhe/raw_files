# %%
import pandas as pd # for reading data
import numpy as np # for numrical calculation
import matplotlib.pyplot as plt #for visualization
import seaborn as sns #for visualization
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from datetime import date
from statistics import mode

# %%
df = pd.read_csv('DataSet.csv')

# %%
df.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409-8743  Female   36                   62.0
# 1  2015       100643  340-5930  Female   39                  149.0
# 2  2015       100756  372-3750  Female   65                  126.0
# 3  2015       101595  331-4902  Female   24                  131.0
# 4  2015       101653  351-8398  Female   40                  191.0
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 2           no              no                87.30                11.9
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               16.81                     82             1.0
# 1               33.37                     87             3.0
# 2                9.89                     91             1.0
# 3               36.41                    102             4.0
# 4               27.54                     83             7.0
#
#   maximum_days_inactive  customer_support_calls  churn
# 0                     4                       1    0.0
# 1                     3                       2    0.0
# 2                     4                       5    1.0
# 3                     3                       3    0.0
# 4                     3                       1    0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  1976 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   1980 non-null   float64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     1990 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          1975 non-null   float64
#  13  maximum_days_inactive   1972 non-null   object
#  14  customer_support_calls  2000 non-null   int64
#  15  churn                   1965 non-null   float64
# dtypes: float64(6), int64(5), object(5)
# memory usage: 250.1+ KB

# %%
df.nunique()
# Out:
# year                         2
# customer_id               1999
# phone_no                  2000
# gender                       6
# age                         63
# no_of_days_subscribed      204
# multi_screen                 2
# mail_subscribed              6
# weekly_mins_watched       1248
# minimum_daily_mins         149
# maximum_daily_mins        1260
# weekly_max_night_mins      111
# videos_watched              19
# maximum_days_inactive        8
# customer_support_calls      10
# churn                        2
# dtype: int64

# %%
df.describe()
# Out:
#               year    customer_id         age  no_of_days_subscribed  \
# count  2000.000000    2000.000000  2000.00000            1980.000000
# mean   2015.322000  554887.157500    38.69050              99.888384
# std       1.466762  261033.690318    10.20641              39.727167
# min    2015.000000  100198.000000    18.00000               1.000000
# 25%    2015.000000  328634.750000    32.00000              73.000000
# 50%    2015.000000  567957.500000    37.00000              99.000000
# 75%    2015.000000  773280.250000    44.00000             127.000000
# max    2022.000000  999961.000000    82.00000             243.000000
#
#        weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# count          1990.000000         2000.000000         2000.000000
# mean            454.721809           10.198700           30.620780
# std            2235.190834            2.785519            9.129165
# min               0.000000            0.000000            0.000000
# 25%             219.450000            8.400000           24.735000
# 50%             271.875000           10.200000           30.590000
# 75%             326.212500           12.000000           36.797500
# max           27990.000000           20.000000           59.640000
#
#        weekly_max_night_mins  videos_watched  customer_support_calls  \
# count            2000.000000     1975.000000             2000.000000
# mean              100.415500        4.488608                1.547000
# std                19.529454        2.491067                1.315164
# min                42.000000        0.000000                0.000000
# 25%                87.000000        3.000000                1.000000
# 50%               101.000000        4.000000                1.000000
# 75%               114.000000        6.000000                2.000000
# max               175.000000       19.000000                9.000000
#
#              churn
# count  1965.000000
# mean      0.133333
# std       0.340021
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
df.columns
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %%
# drooping some columns
df.drop(['year', 'customer_id', 'phone_no'], axis = 1, inplace = True)

# %%
df.head(50)
# Out:
#     gender  age  no_of_days_subscribed multi_screen mail_subscribed  \
# 0   Female   36                   62.0           no              no
# 1   Female   39                  149.0           no              no
# 2   Female   65                  126.0           no              no
# 3   Female   24                  131.0           no             yes
# 4   Female   40                  191.0           no              no
# 5      NaN   31                   65.0           no              no
# 6      NaN   54                   59.0           no              no
# 7   Female   40                   50.0           no              no
# 8     Male   61                  205.0           no             yes
# 9     Male   31                   63.0           no              no
# 10    Male   34                  114.0           no             yes
# 11    Male   34                  107.0           no              no
# 12  Female   30                   84.0           no              no
# 13  Female   23                  142.0           no              no
# 14  Female   21                  137.0           no              no
# 15    Male   30                  100.0           no             yes
# 16    Male   44                   84.0           no              no
# 17  Female   45                   99.0           no              no
# 18    Male   39                  115.0           no              no
# 19  Female   59                  194.0           no              no
# 20     NaN   57                  104.0           no              no
# 21     NaN   32                  170.0           no              no
# 22  Female   45                   76.0           no              no
# 23    Male   32                   94.0           no              no
# 24  Female   36                   81.0           no             yes
# 25    Male   50                  137.0           no              no
# 26    Male   28                  119.0          yes             yes
# 27    Male   37                  138.0           no             yes
# 28  Female   44                  124.0           no              no
# 29    Male   37                   48.0           no             yes
# 30  Female   63                  106.0           no              no
# 31    Male   45                  161.0           no              no
# 32    Male   33                   89.0           no              no
# 33  Female   34                  105.0          yes             yes
# 34  Female   32                   59.0           no              no
# 35  Female   32                   81.0           no              no
# 36    Male   35                   67.0           no              no
# 37    Male   52                  129.0           no              no
# 38     NaN   48                   56.0           no              no
# 39    Male   30                   62.0           no              no
# 40    Male   55                   95.0           no             yes
# 41  Female   44                   76.0           no              no
# 42  Female   31                   37.0           no              no
# 43  Female   41                   80.0           no              no
# 44  Female   43                  190.0           no              no
# 45  Female   45                  168.0           no             yes
# 46  Female   39                  166.0          yes             yes
# 47  Female   38                   42.0           no              no
# 48    Male   43                   96.0           no              no
# 49  Female   26                   76.0          yes              no
#
#     weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# 0                148.35                12.2               16.81
# 1                294.45                 7.7               33.37
# 2                 87.30                11.9                9.89
# 3                321.30                 9.5               36.41
# 4                243.00                10.9               27.54
# 5                193.65                12.7               21.95
# 6                239.25                10.2               27.12
# 7                196.65                 5.6               22.29
# 8                263.70                 7.8               29.89
# 9                316.80                12.3               35.90
# 10               338.70                 8.4               38.39
# 11               201.00                 7.3               22.78
# 12               112.95                12.3               12.80
# 13               218.10                10.9               24.72
# 14               313.20                11.1               35.50
# 15               328.05                12.1               37.18
# 16               239.25                 7.2               27.12
# 17               300.00                11.4               34.00
# 18               367.50                13.7               41.65
# 19                72.60                18.2                8.23
# 20               246.30                10.7               27.91
# 21               369.60                 9.1               41.89
# 22               395.10                11.4               44.78
# 23               206.25                13.4               23.38
# 24               251.85                 9.2               28.54
# 25               363.15                14.7               41.16
# 26               240.00                 8.7               27.20
# 27               275.85                15.0               31.26
# 28               197.70                11.3               22.41
# 29               346.35                 7.6               39.25
# 30               280.65                11.0               31.81
# 31               499.35                 5.4               56.59
# 32               123.45                 7.2               13.99
# 33               234.15                14.7               26.54
# 34               273.75                11.3               31.03
# 35               218.10                 5.2               24.72
# 36               228.75                 4.9               25.93
# 37               324.00                 4.9               36.72
# 38               205.80                14.3               23.32
# 39               220.65                12.2               25.01
# 40               391.20                10.1               44.34
# 41               336.60                 6.7               38.15
# 42               286.65                12.9               32.49
# 43               483.45                 6.7               54.79
# 44               254.10                 8.9               28.80
# 45               146.10                11.4               16.56
# 46               192.30                 8.8               21.79
# 47               361.80                10.6               41.00
# 48               390.60                11.5               44.27
# 49               409.95                12.0               46.46
#
#     weekly_max_night_mins  videos_watched maximum_days_inactive  \
# 0                      82             1.0                     4
# 1                      87             3.0                     3
# 2                      91             1.0                     4
# 3                     102             4.0                     3
# 4                      83             7.0                     3
# 5                     111             6.0                     4
# 6                     106             4.0                   NaN
# 7                      88             9.0                   NaN
# 8                      64             5.0                     3
# 9                      58             2.0                     4
# 10                    100             9.0                     3
# 11                     79             3.0                     2
# 12                    134             1.0                     4
# 13                     96             1.0                     3
# 14                    130             5.0                     3
# 15                    117             4.0                     4
# 16                     82             4.0                     2
# 17                     82             2.0                     4
# 18                    124             8.0                     4
# 19                     87             1.0                     5
# 20                    117             8.0                     3
# 21                     95             8.0                     3
# 22                    101             5.0                     4
# 23                    131             2.0                     4
# 24                    103             6.0                     3
# 25                     50             2.0                     4
# 26                    107             5.0                     3
# 27                    125             3.0                     5
# 28                    101             2.0                     4
# 29                     87             4.0                   NaN
# 30                     81             3.0                   NaN
# 31                    128             9.0                     2
# 32                     70             4.0                     2
# 33                     95             3.0                     4
# 34                    100             8.0                     4
# 35                    109             4.0                     2
# 36                    104             3.0                     2
# 37                    109            10.0                     2
# 38                     72             4.0                     4
# 39                    115             3.0                     4
# 40                     97             5.0                     3
# 41                     74             2.0                     2
# 42                    117             1.0                     4
# 43                    123             8.0                     2
# 44                     93             5.0                     3
# 45                    124             2.0                     4
# 46                    130             7.0                     3
# 47                     91             4.0                     3
# 48                     87             4.0                     4
# 49                     84             7.0                     4
#
#     customer_support_calls  churn
# 0                        1    0.0
# 1                        2    0.0
# 2                        5    1.0
# 3                        3    0.0
# 4                        1    0.0
# 5                        4    1.0
# 6                        0    0.0
# 7                        5    1.0
# 8                        2    0.0
# 9                        0    0.0
# 10                       4    0.0
# 11                       3    0.0
# 12                       1    0.0
# 13                       1    0.0
# 14                       0    0.0
# 15                       1    0.0
# 16                       2    0.0
# 17                       3    0.0
# 18                       1    1.0
# 19                       1    0.0
# 20                       1    0.0
# 21                       0    0.0
# 22                       1    1.0
# 23                       0    0.0
# 24                       4    1.0
# 25                       3    0.0
# 26                       5    1.0
# 27                       1    0.0
# 28                       1    0.0
# 29                       3    0.0
# 30                       1    0.0
# 31                       4    1.0
# 32                       1    0.0
# 33                       0    1.0
# 34                       4    0.0
# 35                       1    0.0
# 36                       2    0.0
# 37                       2    0.0
# 38                       1    0.0
# 39                       0    0.0
# 40                       1    0.0
# 41                       2    0.0
# 42                       0    0.0
# 43                       0    1.0
# 44                       1    0.0
# 45                       2    0.0
# 46                       2    0.0
# 47                       0    0.0
# 48                       5    0.0
# 49                       1    1.0

# %%
df.isnull().sum()
# Out:
# gender                    24
# age                        0
# no_of_days_subscribed     20
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched       10
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched            25
# maximum_days_inactive     28
# customer_support_calls     0
# churn                     35
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['gender'].value_counts()
# Out:
# Male      1048
# Female     918
# 1            4
# 0            4
# 9            1
# 4            1
# Name: gender, dtype: int64

# %%
plt.figure(figsize= (15,8))
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df['gender'].
