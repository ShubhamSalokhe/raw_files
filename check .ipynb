# %%
import random
import string
def shorten_url():
    letters = string.ascii_lowercase + string.ascii_uppercase+string.digits
    while True:
        random_letters = random.choices(letters, k=6)
        random_letters = "".join(random_letters)
        return random_letters
#         short_url = url.query.filter_by(short=random_letters).first()
        if not short_url:
            return random_letters

# %%
shorten_url()

# %%
import random, string
def shorten_url():
    letters = string.ascii_lowercase + string.ascii_uppercase + string.digits
    while True:
        rand_letters = random.choices(letters, k=10)
        rand_letters = "".join(rand_letters)
        return rand_letters
#         short_url = Url.query.filter_by(short=rand_letters).first()
#         if not short_url:

# %%
shorten_url()

# %%
print(random.randint(1000,9999))

# %%
import hashlib as hlb
original_url="https://github.com/ShubhamSalokhe/REGex-Tasks/tree/main/Task%2010"
shorten_url =hlb.md5(original_url.encode("utf-8")).hexdigest()[:9][::-1]
print(shorten_url)

# %%
import PyPDF2 as pdf
import pandas as pd

# %%
df = open('CummulativeCovidVaccinationReport07January2022.pdf',"rb")

# %%
pdfReader = pdf.PdfFileReader(df)
pageObj = pdfReader.getPage(0)
extract= pageObj.extractText()
splitex= extract.split('\n')

# %%
splitex
# Out:
# ["(As on 08 Jan'22 at 7 AM)",
#  '15-18 Years',
#  '1st Dose',
#  '2nd Dose',
#  'Total Doses',
#  '1st Dose',
#  '85,83,23,079',
#  '62,76,35,244',
#  '1,48,59,58,323',
#  '2,02,34,580',
#  '(22,72,120 in last 24 ',
#  'Hours )',
#  '(35,31,325 in last 24 ',
#  'Hours)',
#  '(58,03,445 in last 24 ',
#  'Hours)',
#  '(32,55,915 in last 24 ',
#  'Hours )',
#  '0',
#  '0',
#  '0',
#  '0',
#  '15-18 Years',
#  '1st Dose',
#  '2nd Dose',
#  'Total Doses',
#  '1st Dose',
#  '1',
#  'A & N Islands',
#  '3,03,740',
#  '2,95,713',
#  '5,99,453',
#  '9,968',
#  '2',
#  'Andhra Pradesh',
#  '4,00,82,487',
#  '3,07,28,752',
#  '7,08,11,239',
#  '17,99,919',
#  '3',
#  'Arunachal Pradesh',
#  '8,11,910',
#  '6,55,590',
#  '14,67,500',
#  '12,199',
#  '4',
#  'Assam',
#  '2,19,27,601',
#  '1,62,50,752',
#  '3,81,78,353',
#  '5,45,176',
#  '5',
#  'Bihar',
#  '5,84,94,171',
#  '4,33,15,480',
#  '10,18,09,651',
#  '13,33,297',
#  '6',
#  'Chandigarh',
#  '10,28,191',
#  '7,97,205',
#  '1825396',
# ...

# %%
states = ['A & N Islands',
 'Andhra Pradesh',
 'Arunachal Pradesh',
 'Assam',
 'Bihar',
 'Chandigarh',
 'Chhattisgarh',
 'Dadra & Nagar Haveli',
 'Daman & Diu',
 'Delhi',
 'Goa',
 'Gujarat',
 'Haryana',
 'Himachal Pradesh',
 'Jammu & Kashmir',
 'Jharkhand',
 'Karnataka',
 'Kerala',
 'Ladakh',
 'Lakshadweep',
 'Madhya Pradesh',
 'Maharashtra',
 'Manipur',
 'Meghalaya',
 'Mizoram',
 'Nagaland',
 'Odisha',
 'Puducherry',
 'Punjab',
 'Rajasthan',
 'Sikkim',
 'Tamil Nadu',
 'Telangana',
 'Tripura',
 'Uttar Pradesh',
 'Uttarakhand',
 'West Bengal']

# %%
pd.DataFrame({"State":states}).to_csv("states.csv",index_label=False)

# %%
states  = pd.read_csv("states.csv")
len(states)
# Out:
# 37

# %%
states= states["State"].values
# Out:
# array(['A & N Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam',
#        'Bihar', 'Chandigarh', 'Chhattisgarh', 'Dadra & Nagar Haveli',
#        'Daman & Diu', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Ladakh', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %%
len(states)
# Out:
# 37

# %%
state_doses = pd.DataFrame({"state":[],
               "state_num":[],
               "1st Dose":[],
               "2nd Dose":[],
               "Total Doses":[],
               "1st Dose(15-18)":[]
                })

# %%
states[0:7]

# %%
for i in states:
    if i != 'Dadra & Nagar Haveli':
        index = splitex.index(i)
        state_no = int(splitex[index-1])
        state_name = splitex[index]
        stname_no = [state_name,state_no]
        doses= splitex[index+1:index+5]
        total = stname_no +[int(i.replace(",","")) for i in doses]
        state_doses= state_doses.append(pd.Series(total,["state","state_num","1st Dose", "2nd Dose","Total Doses","1st Dose(15-18)"]),ignore_index=True)  
        
    elif i == 'Dadra & Nagar Haveli':
        index = splitex.index("Dadra & Nagar ")
        state_no = int(splitex[index-1])
        state_name = i
        stname_no = [state_name,state_no]
        state_name = splitex[index]
        doses= splitex[index+2:index+6]
        total = stname_no +[int(i.replace(",","")) for i in doses]
        state_doses=state_doses.append(pd.Series(total,["state","state_num","1st Dose", "2nd Dose","Total Doses","1st Dose(15-18)"]),ignore_index=True)

# %%
state_doses
# Out:
#                    state  state_num     1st Dose    2nd Dose  Total Doses  \
# 0          A & N Islands        1.0     303740.0    295713.0     599453.0
# 1         Andhra Pradesh        2.0   40082487.0  30728752.0   70811239.0
# 2      Arunachal Pradesh        3.0     811910.0    655590.0    1467500.0
# 3                  Assam        4.0   21927601.0  16250752.0   38178353.0
# 4                  Bihar        5.0   58494171.0  43315480.0  101809651.0
# 5             Chandigarh        6.0    1028191.0    797205.0    1825396.0
# 6           Chhattisgarh        7.0   17977433.0  12578825.0   30556258.0
# 7   Dadra & Nagar Haveli        8.0     414480.0    294941.0     709421.0
# 8            Daman & Diu        9.0     293562.0    243997.0     537559.0
# 9                  Delhi       10.0   15603453.0  11573778.0   27177231.0
# 10                   Goa       11.0    1319508.0   1120515.0    2440023.0
# 11               Gujarat       12.0   47582358.0  43384764.0   90967122.0
# ...

# %%
for i in states[0:7]:
    index = splitex.index(i)
    state_no = int(splitex[index-1])
    state_name = splitex[index]
    stname_no = [state_name,state_no]
    doses= splitex[index+1:index+5]
    total = stname_no +[int(i.replace(",","")) for i in doses]
    state_doses =state_doses.append(pd.Series(total,["state","state_num","1st Dose", "2nd Dose","Total Doses","1st Dose(15-18)"]),ignore_index=True)
print(state_doses.head())

# %%
display(state_doses)

# %%
index = splitex.index('A & N Islands')
state_no = int(splitex[index-1])
state_name = splitex[index]
stname_no = [state_name,state_no]
doese= splitex[index+1:index+5]


total_doses =[int(i.replace(",","")) for i in doses]
state_doses.append(pd.Series(total,["state","state_num","1st_Dose", "2nd_Dose","Total_Doses","1st_Dose(15-18)"]),ignore_index=True)
df2 = {'state':(splitex[index]) , 'state_num': int(splitex[index-1]), '1st_Dose': total_doses[0],'2nd_Dose': total_doses[1],'Total_Doses': total_doses[2], '1st_Dose(15-18)': total_doses[3]}
df = df.append(df2, ignore_index = True)

# %%
total

# %%
state_doses.append(pd.Series(total,["state","state_num","1st Dose", "2nd Dose","Total Doses","1st Dose(15-18)"]),ignore_index=True)

# %%
state_doses.info()

# %%
import re

# %%
items = ['goal', 'new', 'user', 'sit', 'eat', 'dinner']

x = [w for w in items if not re.search(r'e',w, re.IGNORECASE)]

# %%
x
# Out:
# ['goal', 'sit']

# %%
ip = 'This note should not be NoTeD'
re.sub(r'note|NoTe','X',ip)
# Out:
# 'This X should not be XD'

# %%
para = '''good start
Start working on that
project you always wanted
stars are shining brightly
hi there
start and try to
finish the book
bye'''

# %%
pat = re.compile('Start|starts',re.I)

# %%
for line in para.split('\n'):
    if not pat.search(line):
        print(line)
# Out:
# project you always wanted
# stars are shining brightly
# hi there
# finish the book
# bye

# %%
items = ['goal', 'new', 'user', 'sit', 'eat', 'dinner']
[w for w in items if re.search('a',w) or re.search('w',w)]
# Out:
# ['goal', 'new', 'eat']

# %%
items = ['goal', 'new', 'user', 'sit', 'eat', 'dinner']
[w for w in items if re.search('e',w) and re.search('n',w)]
# Out:
# ['new', 'dinner']

# %%
ip = 'start address: 0xA0, func1 address: 0xC0'
